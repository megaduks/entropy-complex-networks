# %%
import os;
os.chdir(os.path.dirname(os.getcwd()))
import pandas as pd
import numpy as np
import scikit_posthocs as sp
from scipy.stats import friedmanchisquare

# %% [markdown]
# Definicja progu p-value

# %%
P_VALUE_THRESHOLD = 0.05

# %% [markdown]
# Wczytanie danych

# %%
df = pd.read_csv('results/all_inverted_estimators.csv', header=0)
df = df[df.dataset != 'load_dermatology']
df = df[df.dataset != 'load_lenses']
df['weighted'].fillna('none', inplace=True)
df['categorical'].fillna('none', inplace=True)
df['numerical'].fillna('none', inplace=True)
df['density'].fillna(0.0, inplace=True)

### density 0.075

df_pivoted = df[df['density'].isin([0.0, 0.075])]
df_pivoted = df_pivoted.pivot_table(index=['dataset', 'estimator', 'metric'], columns=['weighted', 'categorical', 'numerical'],
                                    values='score', aggfunc=np.sum).reset_index()

# %%
df
# Out:
#                   dataset           estimator  \
# 0      load_balance_scale  AdaBoostClassifier
# 1      load_balance_scale  AdaBoostClassifier
# 2      load_balance_scale  AdaBoostClassifier
# 3      load_balance_scale  AdaBoostClassifier
# 4      load_balance_scale  AdaBoostClassifier
# 5      load_balance_scale  AdaBoostClassifier
# 6      load_balance_scale  AdaBoostClassifier
# 7      load_balance_scale  AdaBoostClassifier
# 8      load_balance_scale  AdaBoostClassifier
# 9      load_balance_scale  AdaBoostClassifier
# 10     load_balance_scale  AdaBoostClassifier
# 11     load_balance_scale  AdaBoostClassifier
# 12     load_balance_scale  AdaBoostClassifier
# 13     load_balance_scale  AdaBoostClassifier
# 14     load_balance_scale  AdaBoostClassifier
# 15     load_balance_scale  AdaBoostClassifier
# 16     load_balance_scale  AdaBoostClassifier
# 17     load_balance_scale  AdaBoostClassifier
# 18     load_balance_scale  AdaBoostClassifier
# 19     load_balance_scale  AdaBoostClassifier
# 20     load_balance_scale  AdaBoostClassifier
# 21     load_balance_scale  AdaBoostClassifier
# 22     load_balance_scale  AdaBoostClassifier
# 23     load_balance_scale  AdaBoostClassifier
# 24     load_balance_scale  AdaBoostClassifier
# 25     load_balance_scale  AdaBoostClassifier
# 26     load_balance_scale  AdaBoostClassifier
# 27     load_balance_scale  AdaBoostClassifier
# 28     load_balance_scale  AdaBoostClassifier
# 29     load_balance_scale  AdaBoostClassifier
# ...                   ...                 ...
# 11360            load_zoo                 SVC
# 11361            load_zoo                 SVC
# 11362            load_zoo                 SVC
# 11363            load_zoo                 SVC
# 11364            load_zoo                 SVC
# 11365            load_zoo                 SVC
# 11366            load_zoo                 SVC
# 11367            load_zoo                 SVC
# 11368            load_zoo                 SVC
# 11369            load_zoo                 SVC
# 11370            load_zoo                 SVC
# 11371            load_zoo                 SVC
# 11372            load_zoo                 SVC
# 11373            load_zoo                 SVC
# 11374            load_zoo                 SVC
# 11375            load_zoo                 SVC
# 11376            load_zoo                 SVC
# 11377            load_zoo                 SVC
# 11378            load_zoo                 SVC
# 11379            load_zoo                 SVC
# 11380            load_zoo                 SVC
# 11381            load_zoo                 SVC
# 11382            load_zoo                 SVC
# 11383            load_zoo                 SVC
# 11384            load_zoo                 SVC
# 11385            load_zoo                 SVC
# 11386            load_zoo                 SVC
# 11387            load_zoo                 SVC
# 11388            load_zoo                 SVC
# 11389            load_zoo                 SVC
#
#                                weighted  density categorical  numerical  \
# 0                                  none    0.000        none       none
# 1                                  none    0.000        none       none
# 2                                  none    0.000        none       none
# 3                                  none    0.000        none       none
# 4                                  none    0.000        none       none
# 5                     weight_by_entropy    0.075   goodall_3  euclidean
# 6                     weight_by_entropy    0.075   goodall_3  euclidean
# 7                     weight_by_entropy    0.075   goodall_3  euclidean
# 8                     weight_by_entropy    0.075   goodall_3  euclidean
# 9                     weight_by_entropy    0.075   goodall_3  euclidean
# 10                    weight_by_entropy    0.075   goodall_3  manhattan
# 11                    weight_by_entropy    0.075   goodall_3  manhattan
# 12                    weight_by_entropy    0.075   goodall_3  manhattan
# 13                    weight_by_entropy    0.075   goodall_3  manhattan
# 14                    weight_by_entropy    0.075   goodall_3  manhattan
# 15                    weight_by_entropy    0.075     overlap  euclidean
# 16                    weight_by_entropy    0.075     overlap  euclidean
# 17                    weight_by_entropy    0.075     overlap  euclidean
# 18                    weight_by_entropy    0.075     overlap  euclidean
# 19                    weight_by_entropy    0.075     overlap  euclidean
# 20                    weight_by_entropy    0.075     overlap  manhattan
# 21                    weight_by_entropy    0.075     overlap  manhattan
# 22                    weight_by_entropy    0.075     overlap  manhattan
# 23                    weight_by_entropy    0.075     overlap  manhattan
# 24                    weight_by_entropy    0.075     overlap  manhattan
# 25                   weight_by_pagerank    0.075   goodall_3  euclidean
# 26                   weight_by_pagerank    0.075   goodall_3  euclidean
# 27                   weight_by_pagerank    0.075   goodall_3  euclidean
# 28                   weight_by_pagerank    0.075   goodall_3  euclidean
# 29                   weight_by_pagerank    0.075   goodall_3  euclidean
# ...                                 ...      ...         ...        ...
# 11360  weight_by_betweenness_centrality    0.075     overlap  euclidean
# 11361  weight_by_betweenness_centrality    0.075     overlap  euclidean
# 11362  weight_by_betweenness_centrality    0.075     overlap  euclidean
# 11363  weight_by_betweenness_centrality    0.075     overlap  euclidean
# 11364  weight_by_betweenness_centrality    0.075     overlap  euclidean
# 11365  weight_by_betweenness_centrality    0.075     overlap  manhattan
# 11366  weight_by_betweenness_centrality    0.075     overlap  manhattan
# 11367  weight_by_betweenness_centrality    0.075     overlap  manhattan
# 11368  weight_by_betweenness_centrality    0.075     overlap  manhattan
# 11369  weight_by_betweenness_centrality    0.075     overlap  manhattan
# 11370                  weight_by_degree    0.075   goodall_3  euclidean
# 11371                  weight_by_degree    0.075   goodall_3  euclidean
# 11372                  weight_by_degree    0.075   goodall_3  euclidean
# 11373                  weight_by_degree    0.075   goodall_3  euclidean
# 11374                  weight_by_degree    0.075   goodall_3  euclidean
# 11375                  weight_by_degree    0.075   goodall_3  manhattan
# 11376                  weight_by_degree    0.075   goodall_3  manhattan
# 11377                  weight_by_degree    0.075   goodall_3  manhattan
# 11378                  weight_by_degree    0.075   goodall_3  manhattan
# 11379                  weight_by_degree    0.075   goodall_3  manhattan
# 11380                  weight_by_degree    0.075     overlap  euclidean
# 11381                  weight_by_degree    0.075     overlap  euclidean
# 11382                  weight_by_degree    0.075     overlap  euclidean
# 11383                  weight_by_degree    0.075     overlap  euclidean
# 11384                  weight_by_degree    0.075     overlap  euclidean
# 11385                  weight_by_degree    0.075     overlap  manhattan
# 11386                  weight_by_degree    0.075     overlap  manhattan
# 11387                  weight_by_degree    0.075     overlap  manhattan
# 11388                  weight_by_degree    0.075     overlap  manhattan
# 11389                  weight_by_degree    0.075     overlap  manhattan
#
#                    metric  t_interval_lower  t_interval_upper     score
# 0          accuracy_score          0.873750          0.940484  0.907117
# 1       cohen_kappa_score          0.788042          0.897355  0.842699
# 2             f1_weighted          0.892888          0.945689  0.919288
# 3      precision_weighted          0.922114          0.958483  0.940299
# 4         recall_weighted          0.873750          0.940484  0.907117
# 5          accuracy_score          0.838376          0.918409  0.878392
# 6       cohen_kappa_score          0.741723          0.865584  0.803653
# 7             f1_weighted          0.874471          0.930455  0.902463
# 8      precision_weighted          0.949751          0.963997  0.956874
# 9         recall_weighted          0.838376          0.918409  0.878392
# 10         accuracy_score          0.838376          0.918409  0.878392
# 11      cohen_kappa_score          0.741723          0.865584  0.803653
# 12            f1_weighted          0.874471          0.930455  0.902463
# 13     precision_weighted          0.949751          0.963997  0.956874
# 14        recall_weighted          0.838376          0.918409  0.878392
# 15         accuracy_score          0.790121          0.883356  0.836738
# 16      cohen_kappa_score          0.675468          0.810601  0.743034
# 17            f1_weighted          0.838353          0.903917  0.871135
# 18     precision_weighted          0.941586          0.958601  0.950093
# 19        recall_weighted          0.790121          0.883356  0.836738
# 20         accuracy_score          0.790121          0.883356  0.836738
# 21      cohen_kappa_score          0.675468          0.810601  0.743034
# 22            f1_weighted          0.838353          0.903917  0.871135
# 23     precision_weighted          0.941586          0.958601  0.950093
# 24        recall_weighted          0.790121          0.883356  0.836738
# 25         accuracy_score          0.867459          0.934026  0.900742
# 26      cohen_kappa_score          0.784002          0.888833  0.836418
# 27            f1_weighted          0.893039          0.942833  0.917936
# 28     precision_weighted          0.944737          0.967819  0.956278
# 29        recall_weighted          0.867459          0.934026  0.900742
# ...                   ...               ...               ...       ...
# 11360      accuracy_score          0.838863          0.981137  0.910000
# 11361   cohen_kappa_score          0.778796          0.972734  0.875765
# 11362         f1_weighted          0.808799          0.972637  0.890718
# 11363  precision_weighted          0.797936          0.968255  0.883095
# 11364     recall_weighted          0.838863          0.981137  0.910000
# 11365      accuracy_score          0.838863          0.981137  0.910000
# 11366   cohen_kappa_score          0.778796          0.972734  0.875765
# 11367         f1_weighted          0.808799          0.972637  0.890718
# 11368  precision_weighted          0.797936          0.968255  0.883095
# 11369     recall_weighted          0.838863          0.981137  0.910000
# 11370      accuracy_score          0.687132          0.854686  0.770909
# 11371   cohen_kappa_score          0.551685          0.780742  0.666214
# 11372         f1_weighted          0.621257          0.816746  0.719001
# 11373  precision_weighted          0.583589          0.810173  0.696881
# 11374     recall_weighted          0.687132          0.854686  0.770909
# 11375      accuracy_score          0.687132          0.854686  0.770909
# 11376   cohen_kappa_score          0.551685          0.780742  0.666214
# 11377         f1_weighted          0.621257          0.816746  0.719001
# 11378  precision_weighted          0.583589          0.810173  0.696881
# 11379     recall_weighted          0.687132          0.854686  0.770909
# 11380      accuracy_score          0.832556          0.967444  0.900000
# 11381   cohen_kappa_score          0.758522          0.953275  0.855898
# 11382         f1_weighted          0.782621          0.951542  0.867082
# 11383  precision_weighted          0.753926          0.942265  0.848095
# 11384     recall_weighted          0.832556          0.967444  0.900000
# 11385      accuracy_score          0.832556          0.967444  0.900000
# 11386   cohen_kappa_score          0.758522          0.953275  0.855898
# 11387         f1_weighted          0.782621          0.951542  0.867082
# 11388  precision_weighted          0.753926          0.942265  0.848095
# 11389     recall_weighted          0.832556          0.967444  0.900000
#
# [10710 rows x 10 columns]

# %%
unweighted = df_pivoted['none'].values
unweighted = unweighted[:, 0]

pagerank = df_pivoted['weight_by_pagerank']
pagerank_np = pagerank.values

# %% [markdown]
# Wyliczenia testu friedmana dla wersji niezmodyfikowanej (unweighted) i poszczególnych wersji ważenia przez pagerank

# %%
fm, p = friedmanchisquare(unweighted, pagerank_np[:, 0], pagerank_np[:, 1], pagerank_np[:, 2], pagerank_np[:, 3])

print("Friedman for pagerank weighting:")
print(fm)
print('{:.20f}'.format(p))
# Out:
# Friedman for pagerank weighting:
# 62.30245746691977
# 0.00000000000095146065

# %% [markdown]
# Otrzymana p-value jest dużo mniejsze niż zadany próg istotności, a więc odrzucamy hipotezę zerową że między pomiarami nie ma różnicy. W związky tym przeprowadzamy jeden z testów post hoc w tym wypadku test nemenyi.

# %%
if p < P_VALUE_THRESHOLD:
    none_and_pagerank = pagerank.copy()
    none_and_pagerank.insert(0, 'none', df_pivoted['none'])
    post_p = sp.posthoc_nemenyi_friedman(none_and_pagerank.values)
    print("Post hoc test p-value:")
    print(post_p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-cd930d9e396a> in <module>()
#       1 if p < P_VALUE_THRESHOLD:
#       2     none_and_pagerank = pagerank.copy()
# ----> 3     none_and_pagerank.insert(0, 'none', df_pivoted['none'])
#       4     post_p = sp.posthoc_nemenyi_friedman(none_and_pagerank.values)
#       5     print("Post hoc test p-value:")
#
# ~/.virtualenvs/python3/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2611         value = self._sanitize_column(column, value, broadcast=False)
#    2612         self._data.insert(loc, column, value,
# -> 2613                           allow_duplicates=allow_duplicates)
#    2614
#    2615     def assign(self, **kwargs):
#
# ~/.virtualenvs/python3/lib/python3.6/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4061         if not allow_duplicates and item in self.items:
#    4062             # Should this be a different kind of error??
# -> 4063             raise ValueError('cannot insert {}, already exists'.format(item))
#    4064
#    4065         if not isinstance(loc, int):
#
# ValueError: cannot insert none, already exists

# %% [markdown]
# Otrzymana wartości wskazują iż między wersją nieważoną (indeks 0 w dataframe), a pozostałymi nadal istnieje statystycznie wiążąca różnica. Odrzucamy hipotezę zerową mówiącą, iż pomiary nie są różne.
#
# Sprawdzamy jakie jest rankowanie pomiędzy pomiarami.
#
# Pozycja 0 rząd 2 kolumna o wartości 329 oznacza że metoda 0 była lepsza od metody 2 w 329 obserwacjach.
#
# Pozycja 2 rząd 0 kolumna o wartości 231 oznacza że metoda 2 była lepsza od metody 0 w 231 obserwacjach.
#
# Na tej podstawie wnioskuję, że skoro test dowiódł że wyniki metod 0 i 2 są różne, a metoda 0 wygrywa w większej liczbie przypadków to metoda 0 jest metodą skuteczniejszą.

# %%
def _print_ranks(df):
    cols = df.shape[1]
    vs = np.zeros((cols, cols))
    np.fill_diagonal(vs, -1)
    df = df.values
    for i in range(cols):
        for j in range(cols):
            if i != j:
                normal_better = np.where(df[:, i] > df[:, j],
                                         True, False)
                s = (normal_better == True).sum()
                vs[i, j] = s
    return pd.DataFrame(vs)

print("Ranks comparison:")
print(_print_ranks(none_and_pagerank))
# Out:
# Ranks comparison:
#        0      1      2      3
# 0   -1.0  185.0  152.0  222.0
# 1  270.0   -1.0  286.0  151.0
# 2  177.0  263.0   -1.0  212.0
# 3  326.0  178.0  235.0   -1.0
